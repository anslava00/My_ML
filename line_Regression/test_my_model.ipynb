# %%
import MyLinearRegression as mlr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Создадим модель

# %%
liner_model = mlr.MyLinearRegression()

# %% [markdown]
# # Зададим значения для тестирования модели

# %%
df = pd.read_csv('data.csv')

# %%
# df = pd.DataFrame(
#     [[20, 10, 12], [35, 15, 10], [30, 20, 9],
#      [45, 25, 9], [60, 40, 8], [69, 37, 8],
#      [75, 43, 6], [90, 35, 4], [105, 38, 4], [110, 55, 5]],
#     columns=['Y', 'X1', 'X2']
# )

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter( xs=df['rm'], ys=df['medv'])

# %%
y = df.loc[:, 'medv']

# %%
X = df.loc[:, ['rm']]

# %%
liner_model.fit(X, y, type_fit='grad')
# Out:
# Количество итераций: 4151

# %%
liner_model.w
# Out:
# array([[  7.06070484],
#        [-21.68500812]])

# %%
plt.scatter(x=X, y=y)
liner_line = [[i] for i in range(3, 10)]
plt.plot(liner_line, liner_model.predict(liner_line), color='green')

# %%
liner_model.fit(X, y, type_fit='matrix')

# %%
liner_model.w
# Out:
# array([  9.10210898, -34.67062078])

# %%
plt.scatter(x=X, y=y)
liner_line = [[i] for i in range(3, 10)]
plt.plot(liner_line, liner_model.predict(liner_line), color='green')

# %%
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.scatter(xs=df['zn'], ys=df['rm'], zs=df['medv'])
# ax.plot(xs=df['zn'], ys=df['rm'], zs=liner_model.predict(X), color='g')
